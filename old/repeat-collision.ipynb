# %% [markdown]
# ## Comparison of number of repeats before and after mutations
# ###

# %%
import random
import matplotlib.pyplot as plt
# Every read will only have 5 mutations defined at distance

# %%
def random_dna(length):
    return ''.join(random.choice('ACGT') for _ in range(length))


def mutate_sequence(seq, num_mutations):
    seq = list(seq)
    positions = random.sample(range(len(seq)), num_mutations)
    for pos in positions:
        bases = ['A', 'C', 'G', 'T']
        bases.remove(seq[pos])
        seq[pos] = random.choice(bases)
    return ''.join(seq)


def introduce_errors(seq, error_rate):
    seq = list(seq)
    for i in range(len(seq)):
        if random.random() < error_rate:
            bases = ['A', 'C', 'G', 'T']
            bases.remove(seq[i])
            seq[i] = random.choice(bases)
    return ''.join(seq)

def create_repeats(base_seq, distance):
    copy1 = base_seq
    copy2 = mutate_sequence(base_seq, distance)
    return [copy1, copy2]

def simulate_reads(copies, read_length, reads_per_copy, error_rate):
    reads = []
    
    for copy_id, seq in enumerate(copies):
        for _ in range(reads_per_copy):
            start = random.randint(0, len(seq) - read_length)
            read = seq[start:start+read_length]
            read = introduce_errors(read, error_rate)
            
            reads.append({
                "seq": read,
                "true_copy": copy_id
            })
    
    return reads

def detect_collisions(reads, copies):
    collisions = 0
    total = len(reads)
    
    for read in reads:
        read_seq = read["seq"]
        true_id = read["true_copy"]
        
        for other_id, seq in enumerate(copies):
            if other_id == true_id:
                continue
            
            if read_seq in seq:
                collisions += 1
                break
    
    return collisions

# %% [markdown]
# ### Genome length of 1 million base pairs (1)

# %%
genome_length = 1000000
reads_per_copy = 200
error_rate = 0.01
distance_between_copies = 5  # keep this fixed

base_seq = random_dna(genome_length)
copies = create_repeats(base_seq, distance_between_copies)

read_lengths = [20, 30, 50, 75, 100, 150, 200]

results = []

for L in read_lengths:
    reads = simulate_reads(copies, L, reads_per_copy, error_rate)
    collisions = detect_collisions(reads, copies)
    
    print(f"Read length: {L}, Collisions: {collisions:.4f}")
    results.append(collisions)
plt.figure()
plt.plot(read_lengths, results, marker='o')
plt.xlabel("Read length")
plt.ylabel("Collisions")
plt.title("Collisions vs Read Length")
plt.grid()
plt.show()
# Out:
# Read length: 20, Collisions: 334.0000
# Read length: 30, Collisions: 291.0000
# Read length: 50, Collisions: 251.0000
# Read length: 75, Collisions: 191.0000
# Read length: 100, Collisions: 144.0000
# Read length: 150, Collisions: 108.0000
# Read length: 200, Collisions: 53.0000

# %% [markdown]
# ### Genome length of 1 million base pairs (2)

# %%
genome_length = 1000000
reads_per_copy = 200
error_rate = 0.01
distance_between_copies = 5  # keep this fixed

base_seq = random_dna(genome_length)
copies = create_repeats(base_seq, distance_between_copies)

read_lengths = [20, 30, 50, 75, 100, 150, 200]

results = []

for L in read_lengths:
    reads = simulate_reads(copies, L, reads_per_copy, error_rate)
    collisions = detect_collisions(reads, copies)
    
    print(f"Read length: {L}, Collisions: {collisions:.4f}")
    results.append(collisions)

plt.figure()
plt.plot(read_lengths, results, marker='o')
plt.xlabel("Read length")
plt.ylabel("Collisions")
plt.title("Collisions vs Read Length")
plt.grid()
plt.show()
# Out:
# Read length: 20, Collisions: 335.0000
# Read length: 30, Collisions: 310.0000
# Read length: 50, Collisions: 229.0000
# Read length: 75, Collisions: 197.0000
# Read length: 100, Collisions: 153.0000
# Read length: 150, Collisions: 96.0000
# Read length: 200, Collisions: 52.0000

# %% [markdown]
# ### Genome length of 10 million base pairs (1)

# %%
genome_length = 10000000
reads_per_copy = 200
error_rate = 0.01
distance_between_copies = 5  # keep this fixed

base_seq = random_dna(genome_length)
copies = create_repeats(base_seq, distance_between_copies)

read_lengths = [20, 30, 50, 75, 100, 150, 200]

results = []

for L in read_lengths:
    reads = simulate_reads(copies, L, reads_per_copy, error_rate)
    collisions = detect_collisions(reads, copies)
    
    print(f"Read length: {L}, Collisions: {collisions:.4f}")
    results.append(collisions)

plt.figure()
plt.plot(read_lengths, results, marker='o')
plt.xlabel("Read length")
plt.ylabel("Collisions")
plt.title("Collisions vs Read Length")
plt.grid()
plt.show()
# Out:
# Read length: 20, Collisions: 327.0000
# Read length: 30, Collisions: 287.0000
# Read length: 50, Collisions: 244.0000
# Read length: 75, Collisions: 165.0000
# Read length: 100, Collisions: 157.0000
# Read length: 150, Collisions: 63.0000
# Read length: 200, Collisions: 47.0000

# %% [markdown]
# ### Genome length of 10 million base pairs (2)

# %%
genome_length = 10000000
reads_per_copy = 200
error_rate = 0.01
distance_between_copies = 5  # keep this fixed

base_seq = random_dna(genome_length)
copies = create_repeats(base_seq, distance_between_copies)

read_lengths = [20, 30, 50, 75, 100, 150, 200]

results = []

for L in read_lengths:
    reads = simulate_reads(copies, L, reads_per_copy, error_rate)
    collisions = detect_collisions(reads, copies)
    
    print(f"Read length: {L}, Collisions: {collisions:.4f}")
    results.append(collisions)

plt.figure()
plt.plot(read_lengths, results, marker='o')
plt.xlabel("Read length")
plt.ylabel("Collisions")
plt.title("Collisions vs Read Length")
plt.grid()
plt.show()
# Out:
# Read length: 20, Collisions: 319.0000
# Read length: 30, Collisions: 283.0000
# Read length: 50, Collisions: 230.0000
# Read length: 75, Collisions: 163.0000
# Read length: 100, Collisions: 135.0000
# Read length: 150, Collisions: 83.0000
# Read length: 200, Collisions: 51.0000

# %% [markdown]
# ### Genome length of 10 million base pairs (3)

# %%
genome_length = 10000000
reads_per_copy = 200
error_rate = 0.01
distance_between_copies = 5  # keep this fixed

base_seq = random_dna(genome_length)
copies = create_repeats(base_seq, distance_between_copies)

read_lengths = [20, 30, 50, 75, 100, 150, 200]

results = []

for L in read_lengths:
    reads = simulate_reads(copies, L, reads_per_copy, error_rate)
    collisions = detect_collisions(reads, copies)
    
    print(f"Read length: {L}, Collisions: {collisions:.4f}")
    results.append(collisions)

plt.figure()
plt.plot(read_lengths, results, marker='o')
plt.xlabel("Read length")
plt.ylabel("Collisions")
plt.title("Collisions vs Read Length")
plt.grid()
plt.show()
# Out:
# Read length: 20, Collisions: 317.0000
# Read length: 30, Collisions: 292.0000
# Read length: 50, Collisions: 238.0000
# Read length: 75, Collisions: 183.0000
# Read length: 100, Collisions: 138.0000
# Read length: 150, Collisions: 92.0000
# Read length: 200, Collisions: 56.0000
